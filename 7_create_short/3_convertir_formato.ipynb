# %%
import ffmpeg
import os

# %%
# Ruta donde se deben eliminar las carpetas
output_path = 'videos_short_formto_iphone'

# Eliminar todas las carpetas en output_path
if os.path.exists(output_path):
    # Iterar sobre los elementos dentro del directorio
    for item in os.listdir(output_path):
        item_path = os.path.join(output_path, item)
        # Eliminar archivos
        if os.path.isfile(item_path):
            os.remove(item_path)
        # Eliminar carpetas y su contenido de forma recursiva
        elif os.path.isdir(item_path):
            for root, dirs, files in os.walk(item_path, topdown=False):
                for name in files:
                    os.remove(os.path.join(root, name))
                for name in dirs:
                    os.rmdir(os.path.join(root, name))
            os.rmdir(item_path)  # Finalmente eliminar la carpeta vacía
else:
    print(f"The folder {output_path} does not exist.")

# %%
def convert_to_h264(input_file, output_file):
    if not os.path.exists(input_file):
        print(f"Archivo de entrada no encontrado: {input_file}")
        return

    try:
        (
            ffmpeg
            .input(input_file)
            .output(output_file, vcodec='libx264', crf=23, preset='fast', pix_fmt='yuv420p', format='mp4')
            .run(overwrite_output=True)
        )
        print(f"Conversión completada. Archivo guardado en: {output_file}")
    except Exception as e:
        print(f"Ocurrió un error durante la conversión de {input_file}: {e}")

# %%
# Asegurarse de que la carpeta exista después de eliminar su contenido
os.makedirs(output_path, exist_ok=True)

# Ruta de la carpeta de entrada con los archivos .txt
folder_path = '/mnt/D8E84E4DE84E2A58/Env_python/Create_video_news/0_create text/text/en/final/'

# Lista de archivos .txt en la carpeta
files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

# Ordenar los archivos si es necesario
files.sort()

# %%
for i, file in enumerate(files):
    input_path = f'videos_by_news_short/{i+1}.mp4'
    new_file = f'videos_short_formto_iphone/{i+1}.mp4'

    # Verificar si el archivo de entrada existe
    if not os.path.exists(input_path):
        print(f"El archivo de entrada no existe: {input_path}")
        continue

    convert_to_h264(input_path, new_file)
# Out:
# El archivo de entrada no existe: videos_by_news_short/1.mp4
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:19.58, start: 0.000000, bitrate: 1491 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1349 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5869c920bac0] using SAR=1/1
# [libx264 @ 0x5869c920bac0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5869c920bac0] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5869c920bac0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x5869c91ae740] video:546kB audio:317kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.864853%
# frame=  470 fps=309 q=-1.0 Lsize=     879kB time=00:00:19.57 bitrate= 368.1kbits/s speed=12.9x
# [libx264 @ 0x5869c920bac0] frame I:5     Avg QP:10.24  size: 45459
# [libx264 @ 0x5869c920bac0] frame P:120   Avg QP:14.31  size:  1801
# [libx264 @ 0x5869c920bac0] frame B:345   Avg QP:16.50  size:   334
# [libx264 @ 0x5869c920bac0] consecutive B-frames:  1.5%  0.9%  3.2% 94.5%
# [libx264 @ 0x5869c920bac0] mb I  I16..4: 54.9% 36.1%  9.0%
# [libx264 @ 0x5869c920bac0] mb P  I16..4:  0.2%  0.3%  0.1%  P16..4:  2.3%  0.5%  0.3%  0.0%  0.0%    skip:96.2%
# [libx264 @ 0x5869c920bac0] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8:  0.9%  0.1%  0.0%  direct: 0.2%  skip:98.6%  L0:49.4% L1:44.9% BI: 5.7%
# [libx264 @ 0x5869c920bac0] 8x8 transform intra:36.5% inter:59.0%
# [libx264 @ 0x5869c920bac0] coded y,uvDC,uvAC intra: 12.0% 20.2% 13.2% inter: 0.2% 0.5% 0.1%
# [libx264 @ 0x5869c920bac0] i16 v,h,dc,p: 78% 17%  3%  2%
# [libx264 @ 0x5869c920bac0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 52% 21% 19%  1%  2%  3%  1%  0%  1%
# [libx264 @ 0x5869c920bac0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 26% 12%  3%  4%  4%  4%  4%  3%
# [libx264 @ 0x5869c920bac0] i8c dc,h,v,p: 82% 11%  6%  1%
# [libx264 @ 0x5869c920bac0] Weighted P-Frames: Y:4.2% UV:4.2%
# [libx264 @ 0x5869c920bac0] ref P L0: 76.6% 23.4%
# [libx264 @ 0x5869c920bac0] ref B L0: 77.8% 22.2%
# [libx264 @ 0x5869c920bac0] ref B L1: 93.5%  6.5%
# [libx264 @ 0x5869c920bac0] kb/s:228.20
# [aac @ 0x5869c9ff8940] Qavg: 569.489
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:14.92, start: 0.000000, bitrate: 1417 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1275 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 134 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/2.mp4
# [libx264 @ 0x5b3b9a43cf80] using SAR=1/1
# [libx264 @ 0x5b3b9a43cf80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5b3b9a43cf80] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5b3b9a43cf80] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x5b3b9a3e6480] video:486kB audio:241kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.733107%
# frame=  358 fps=300 q=-1.0 Lsize=     740kB time=00:00:14.86 bitrate= 407.9kbits/s speed=12.4x
# [libx264 @ 0x5b3b9a43cf80] frame I:3     Avg QP:13.09  size: 63352
# [libx264 @ 0x5b3b9a43cf80] frame P:90    Avg QP:15.06  size:  2381
# [libx264 @ 0x5b3b9a43cf80] frame B:265   Avg QP:16.57  size:   351
# [libx264 @ 0x5b3b9a43cf80] consecutive B-frames:  1.1%  0.0%  1.7% 97.2%
# [libx264 @ 0x5b3b9a43cf80] mb I  I16..4: 48.9% 38.5% 12.6%
# [libx264 @ 0x5b3b9a43cf80] mb P  I16..4:  1.2%  0.6%  0.1%  P16..4:  2.6%  1.0%  0.6%  0.0%  0.0%    skip:94.1%
# [libx264 @ 0x5b3b9a43cf80] mb B  I16..4:  0.1%  0.1%  0.0%  B16..8:  0.8%  0.2%  0.0%  direct: 0.3%  skip:98.5%  L0:41.5% L1:49.9% BI: 8.5%
# [libx264 @ 0x5b3b9a43cf80] 8x8 transform intra:35.5% inter:61.8%
# [libx264 @ 0x5b3b9a43cf80] coded y,uvDC,uvAC intra: 14.1% 20.2% 10.4% inter: 0.4% 0.6% 0.0%
# [libx264 @ 0x5b3b9a43cf80] i16 v,h,dc,p: 85% 11%  3%  1%
# [libx264 @ 0x5b3b9a43cf80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 43% 15% 34%  1%  1%  1%  2%  1%  2%
# [libx264 @ 0x5b3b9a43cf80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 29% 11%  4%  4%  5%  6%  5%  5%
# [libx264 @ 0x5b3b9a43cf80] i8c dc,h,v,p: 78% 11%  9%  1%
# [libx264 @ 0x5b3b9a43cf80] Weighted P-Frames: Y:1.1% UV:0.0%
# [libx264 @ 0x5b3b9a43cf80] ref P L0: 75.0% 25.0%
# [libx264 @ 0x5b3b9a43cf80] ref B L0: 81.1% 18.9%
# [libx264 @ 0x5b3b9a43cf80] ref B L1: 94.2%  5.8%
# [libx264 @ 0x5b3b9a43cf80] kb/s:266.66
# [aac @ 0x5b3b9b2242c0] Qavg: 571.287
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/3.mp4
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:14.79, start: 0.000000, bitrate: 1801 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1659 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5b7bb0d46f40] using SAR=1/1
# [libx264 @ 0x5b7bb0d46f40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5b7bb0d46f40] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5b7bb0d46f40] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x5b7bb0cf0380] video:1042kB audio:239kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.970621%
# frame=  355 fps=271 q=-1.0 Lsize=    1293kB time=00:00:14.76 bitrate= 717.2kbits/s speed=11.3x
# [libx264 @ 0x5b7bb0d46f40] frame I:5     Avg QP: 9.69  size: 45284
# [libx264 @ 0x5b7bb0d46f40] frame P:106   Avg QP:14.22  size:  5214
# [libx264 @ 0x5b7bb0d46f40] frame B:244   Avg QP:16.36  size:  1175
# [libx264 @ 0x5b7bb0d46f40] consecutive B-frames:  4.5%  9.0%  7.6% 78.9%
# [libx264 @ 0x5b7bb0d46f40] mb I  I16..4: 65.5% 26.0%  8.5%
# [libx264 @ 0x5b7bb0d46f40] mb P  I16..4:  1.3%  2.1%  0.2%  P16..4:  6.8%  1.9%  0.8%  0.0%  0.0%    skip:86.9%
# [libx264 @ 0x5b7bb0d46f40] mb B  I16..4:  0.4%  0.2%  0.0%  B16..8:  3.4%  0.6%  0.0%  direct: 1.1%  skip:94.3%  L0:44.7% L1:48.7% BI: 6.6%
# [libx264 @ 0x5b7bb0d46f40] 8x8 transform intra:39.4% inter:67.9%
# [libx264 @ 0x5b7bb0d46f40] coded y,uvDC,uvAC intra: 14.1% 31.9% 11.7% inter: 0.7% 2.0% 0.2%
# [libx264 @ 0x5b7bb0d46f40] i16 v,h,dc,p: 70% 21%  4%  5%
# [libx264 @ 0x5b7bb0d46f40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 22% 30%  1%  2%  2%  3%  2%  2%
# [libx264 @ 0x5b7bb0d46f40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 26% 12%  4%  5%  5%  4%  5%  4%
# [libx264 @ 0x5b7bb0d46f40] i8c dc,h,v,p: 63% 21% 13%  3%
# [libx264 @ 0x5b7bb0d46f40] Weighted P-Frames: Y:0.9% UV:0.9%
# [libx264 @ 0x5b7bb0d46f40] ref P L0: 72.6% 27.4%
# [libx264 @ 0x5b7bb0d46f40] ref B L0: 81.2% 18.8%
# [libx264 @ 0x5b7bb0d46f40] ref B L1: 96.3%  3.7%
# [libx264 @ 0x5b7bb0d46f40] kb/s:576.45
# [aac @ 0x5b7bb1b21ac0] Qavg: 529.908
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:21.50, start: 0.000000, bitrate: 2187 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 2044 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 136 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/4.mp4
# [libx264 @ 0x64957cef4180] using SAR=1/1
# [libx264 @ 0x64957cef4180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x64957cef4180] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x64957cef4180] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x64957ceae900] video:1576kB audio:347kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.910313%
# frame=  516 fps=276 q=-1.0 Lsize=    1941kB time=00:00:21.45 bitrate= 741.1kbits/s speed=11.5x
# [libx264 @ 0x64957cef4180] frame I:3     Avg QP:13.48  size:100484
# [libx264 @ 0x64957cef4180] frame P:142   Avg QP:14.84  size:  5223
# [libx264 @ 0x64957cef4180] frame B:371   Avg QP:14.89  size:  1537
# [libx264 @ 0x64957cef4180] consecutive B-frames:  2.1%  4.7%  4.1% 89.1%
# [libx264 @ 0x64957cef4180] mb I  I16..4: 41.8% 42.2% 16.0%
# [libx264 @ 0x64957cef4180] mb P  I16..4:  1.2%  3.5%  0.4%  P16..4:  4.2%  1.0%  0.5%  0.0%  0.0%    skip:89.2%
# [libx264 @ 0x64957cef4180] mb B  I16..4:  0.5%  0.9%  0.1%  B16..8:  2.0%  0.5%  0.0%  direct: 0.6%  skip:95.4%  L0:40.9% L1:52.8% BI: 6.3%
# [libx264 @ 0x64957cef4180] 8x8 transform intra:61.5% inter:65.3%
# [libx264 @ 0x64957cef4180] coded y,uvDC,uvAC intra: 35.5% 51.9% 13.9% inter: 0.8% 1.2% 0.1%
# [libx264 @ 0x64957cef4180] i16 v,h,dc,p: 51% 27%  9% 13%
# [libx264 @ 0x64957cef4180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 27% 18%  3%  5%  4%  7%  3%  6%
# [libx264 @ 0x64957cef4180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 26% 12%  5%  7%  6%  8%  5%  6%
# [libx264 @ 0x64957cef4180] i8c dc,h,v,p: 57% 24% 15%  4%
# [libx264 @ 0x64957cef4180] Weighted P-Frames: Y:2.1% UV:2.1%
# [libx264 @ 0x64957cef4180] ref P L0: 77.2% 22.8%
# [libx264 @ 0x64957cef4180] ref B L0: 81.0% 19.0%
# [libx264 @ 0x64957cef4180] ref B L1: 96.1%  3.9%
# [libx264 @ 0x64957cef4180] kb/s:600.28
# [aac @ 0x64957dce9c00] Qavg: 550.793
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:14.33, start: 0.000000, bitrate: 1912 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1769 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 136 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/5.mp4
# [libx264 @ 0x5d0f02ca8240] using SAR=1/1
# [libx264 @ 0x5d0f02ca8240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5d0f02ca8240] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5d0f02ca8240] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x5d0f02c51400] video:1007kB audio:233kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.980363%
# frame=  344 fps=251 q=-1.0 Lsize=    1253kB time=00:00:14.30 bitrate= 717.5kbits/s speed=10.4x
# [libx264 @ 0x5d0f02ca8240] frame I:3     Avg QP:10.30  size: 46112
# [libx264 @ 0x5d0f02ca8240] frame P:93    Avg QP:14.57  size:  6520
# [libx264 @ 0x5d0f02ca8240] frame B:248   Avg QP:16.87  size:  1154
# [libx264 @ 0x5d0f02ca8240] consecutive B-frames:  1.5%  6.4%  2.6% 89.5%
# [libx264 @ 0x5d0f02ca8240] mb I  I16..4: 63.8% 27.4%  8.8%
# [libx264 @ 0x5d0f02ca8240] mb P  I16..4:  0.6%  1.7%  0.3%  P16..4:  7.7%  2.3%  1.2%  0.0%  0.0%    skip:86.1%
# [libx264 @ 0x5d0f02ca8240] mb B  I16..4:  0.2%  0.2%  0.0%  B16..8:  3.7%  0.6%  0.0%  direct: 0.7%  skip:94.5%  L0:36.6% L1:57.0% BI: 6.4%
# [libx264 @ 0x5d0f02ca8240] 8x8 transform intra:45.1% inter:74.4%
# [libx264 @ 0x5d0f02ca8240] coded y,uvDC,uvAC intra: 29.0% 36.2% 18.6% inter: 1.1% 1.9% 0.2%
# [libx264 @ 0x5d0f02ca8240] i16 v,h,dc,p: 73% 17%  4%  6%
# [libx264 @ 0x5d0f02ca8240] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 22% 21%  3%  3%  4%  4%  4%  5%
# [libx264 @ 0x5d0f02ca8240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 24% 10%  5%  6%  6%  6%  6%  5%
# [libx264 @ 0x5d0f02ca8240] i8c dc,h,v,p: 68% 16% 13%  3%
# [libx264 @ 0x5d0f02ca8240] Weighted P-Frames: Y:3.2% UV:2.2%
# [libx264 @ 0x5d0f02ca8240] ref P L0: 75.9% 24.1%
# [libx264 @ 0x5d0f02ca8240] ref B L0: 84.7% 15.3%
# [libx264 @ 0x5d0f02ca8240] ref B L1: 96.2%  3.8%
# [libx264 @ 0x5d0f02ca8240] kb/s:575.43
# [aac @ 0x5d0f03a950c0] Qavg: 580.039
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:14.38, start: 0.000000, bitrate: 1478 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1335 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/6.mp4
# [libx264 @ 0x60cdeba4b240] using SAR=1/1
# [libx264 @ 0x60cdeba4b240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x60cdeba4b240] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x60cdeba4b240] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x60cdeb9f4400] video:507kB audio:233kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.646549%
# frame=  345 fps=279 q=-1.0 Lsize=     753kB time=00:00:14.34 bitrate= 429.9kbits/s speed=11.6x
# [libx264 @ 0x60cdeba4b240] frame I:4     Avg QP:12.06  size: 53314
# [libx264 @ 0x60cdeba4b240] frame P:91    Avg QP:15.67  size:  1395
# [libx264 @ 0x60cdeba4b240] frame B:250   Avg QP:15.31  size:   715
# [libx264 @ 0x60cdeba4b240] consecutive B-frames:  1.4%  4.6%  3.5% 90.4%
# [libx264 @ 0x60cdeba4b240] mb I  I16..4: 54.6% 35.0% 10.5%
# [libx264 @ 0x60cdeba4b240] mb P  I16..4:  1.1%  3.1%  0.1%  P16..4:  3.1%  0.3%  0.1%  0.0%  0.0%    skip:92.3%
# [libx264 @ 0x60cdeba4b240] mb B  I16..4:  0.7%  0.3%  0.0%  B16..8:  2.9%  0.4%  0.0%  direct: 0.1%  skip:95.5%  L0:49.7% L1:47.9% BI: 2.4%
# [libx264 @ 0x60cdeba4b240] 8x8 transform intra:46.5% inter:63.6%
# [libx264 @ 0x60cdeba4b240] coded y,uvDC,uvAC intra: 7.4% 2.6% 1.7% inter: 0.1% 0.0% 0.0%
# [libx264 @ 0x60cdeba4b240] i16 v,h,dc,p: 62% 30%  4%  4%
# [libx264 @ 0x60cdeba4b240] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46% 17% 31%  1%  1%  1%  1%  1%  1%
# [libx264 @ 0x60cdeba4b240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 28% 16%  4%  3%  3%  4%  4%  4%
# [libx264 @ 0x60cdeba4b240] i8c dc,h,v,p: 96%  3%  1%  0%
# [libx264 @ 0x60cdeba4b240] Weighted P-Frames: Y:3.3% UV:3.3%
# [libx264 @ 0x60cdeba4b240] ref P L0: 69.6% 30.4%
# [libx264 @ 0x60cdeba4b240] ref B L0: 85.5% 14.5%
# [libx264 @ 0x60cdeba4b240] ref B L1: 95.9%  4.1%
# [libx264 @ 0x60cdeba4b240] kb/s:288.76
# [aac @ 0x60cdec835980] Qavg: 646.729
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/7.mp4
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:17.63, start: 0.000000, bitrate: 712 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 570 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x63e9052dfc40] using SAR=1/1
# [libx264 @ 0x63e9052dfc40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x63e9052dfc40] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x63e9052dfc40] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x63e9052354c0] video:210kB audio:291kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.921260%
# frame=  423 fps=303 q=-1.0 Lsize=     516kB time=00:00:17.60 bitrate= 240.1kbits/s speed=12.6x
# [libx264 @ 0x63e9052dfc40] frame I:3     Avg QP:10.30  size: 50027
# [libx264 @ 0x63e9052dfc40] frame P:111   Avg QP:13.64  size:   331
# [libx264 @ 0x63e9052dfc40] frame B:309   Avg QP:14.02  size:    90
# [libx264 @ 0x63e9052dfc40] consecutive B-frames:  1.2%  3.3%  2.8% 92.7%
# [libx264 @ 0x63e9052dfc40] mb I  I16..4: 67.4% 24.3%  8.3%
# [libx264 @ 0x63e9052dfc40] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4:  0.4%  0.0%  0.0%  0.0%  0.0%    skip:99.5%
# [libx264 @ 0x63e9052dfc40] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.1%  0.0%  0.0%  direct: 0.0%  skip:99.9%  L0:46.4% L1:48.2% BI: 5.4%
# [libx264 @ 0x63e9052dfc40] 8x8 transform intra:25.1% inter:40.8%
# [libx264 @ 0x63e9052dfc40] coded y,uvDC,uvAC intra: 10.8% 9.0% 8.3% inter: 0.0% 0.0% 0.0%
# [libx264 @ 0x63e9052dfc40] i16 v,h,dc,p: 92%  6%  1%  0%
# [libx264 @ 0x63e9052dfc40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 54% 20% 19%  1%  1%  1%  1%  1%  2%
# [libx264 @ 0x63e9052dfc40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 24% 14%  5%  4%  3%  4%  6%  4%
# [libx264 @ 0x63e9052dfc40] i8c dc,h,v,p: 92%  5%  2%  1%
# [libx264 @ 0x63e9052dfc40] Weighted P-Frames: Y:2.7% UV:2.7%
# [libx264 @ 0x63e9052dfc40] ref P L0: 86.9% 13.1%
# [libx264 @ 0x63e9052dfc40] ref B L0: 84.9% 15.1%
# [libx264 @ 0x63e9052dfc40] ref B L1: 93.2%  6.8%
# [libx264 @ 0x63e9052dfc40] kb/s:97.47
# [aac @ 0x63e90606c140] Qavg: 649.118
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:13.79, start: 0.000000, bitrate: 2385 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 2243 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 134 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/8.mp4
# [libx264 @ 0x6302b86d3e40] using SAR=1/1
# [libx264 @ 0x6302b86d3e40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x6302b86d3e40] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x6302b86d3e40] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# frame=  197 fps=184 q=28.0 size=    1024kB time=00:00:11.63 bitrate= 721.1kbits/s speed=10.8x
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/9.mp4
# [out#0/mp4 @ 0x6302b867d280] video:1692kB audio:223kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.606403%
# frame=  331 fps=232 q=-1.0 Lsize=    1927kB time=00:00:13.74 bitrate=1148.5kbits/s speed=9.65x
# [libx264 @ 0x6302b86d3e40] frame I:3     Avg QP:12.18  size: 25051
# [libx264 @ 0x6302b86d3e40] frame P:116   Avg QP:15.74  size: 10645
# [libx264 @ 0x6302b86d3e40] frame B:212   Avg QP:18.81  size:  1992
# [libx264 @ 0x6302b86d3e40] consecutive B-frames: 10.0% 13.3%  1.8% 74.9%
# [libx264 @ 0x6302b86d3e40] mb I  I16..4: 49.2% 46.6%  4.2%
# [libx264 @ 0x6302b86d3e40] mb P  I16..4:  3.9%  7.1%  0.6%  P16..4:  9.0%  2.7%  1.2%  0.0%  0.0%    skip:75.6%
# [libx264 @ 0x6302b86d3e40] mb B  I16..4:  0.7%  0.8%  0.0%  B16..8:  4.8%  0.7%  0.0%  direct: 1.7%  skip:91.3%  L0:47.5% L1:46.1% BI: 6.4%
# [libx264 @ 0x6302b86d3e40] 8x8 transform intra:57.6% inter:77.4%
# [libx264 @ 0x6302b86d3e40] coded y,uvDC,uvAC intra: 25.3% 57.8% 21.0% inter: 1.7% 3.9% 0.6%
# [libx264 @ 0x6302b86d3e40] i16 v,h,dc,p: 51% 31%  7% 11%
# [libx264 @ 0x6302b86d3e40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 26% 20%  3%  2%  3%  3%  3%  5%
# [libx264 @ 0x6302b86d3e40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 28% 11%  4%  4%  5%  6%  4%  5%
# [libx264 @ 0x6302b86d3e40] i8c dc,h,v,p: 46% 26% 22%  6%
# [libx264 @ 0x6302b86d3e40] Weighted P-Frames: Y:4.3% UV:1.7%
# [libx264 @ 0x6302b86d3e40] ref P L0: 76.7% 23.3%
# [libx264 @ 0x6302b86d3e40] ref B L0: 85.7% 14.3%
# [libx264 @ 0x6302b86d3e40] ref B L1: 97.2%  2.8%
# [libx264 @ 0x6302b86d3e40] kb/s:1004.76
# [aac @ 0x6302b94be200] Qavg: 592.483
