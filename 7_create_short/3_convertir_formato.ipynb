# %%
import ffmpeg
import os

# %%
# Ruta donde se deben eliminar las carpetas
output_path = 'videos_short_formto_iphone'

# Eliminar todas las carpetas en output_path
if os.path.exists(output_path):
    # Iterar sobre los elementos dentro del directorio
    for item in os.listdir(output_path):
        item_path = os.path.join(output_path, item)
        # Eliminar archivos
        if os.path.isfile(item_path):
            os.remove(item_path)
        # Eliminar carpetas y su contenido de forma recursiva
        elif os.path.isdir(item_path):
            for root, dirs, files in os.walk(item_path, topdown=False):
                for name in files:
                    os.remove(os.path.join(root, name))
                for name in dirs:
                    os.rmdir(os.path.join(root, name))
            os.rmdir(item_path)  # Finalmente eliminar la carpeta vacía
else:
    print(f"The folder {output_path} does not exist.")

# %%
def convert_to_h264(input_file, output_file):
    if not os.path.exists(input_file):
        print(f"Archivo de entrada no encontrado: {input_file}")
        return

    try:
        (
            ffmpeg
            .input(input_file)
            .output(output_file, vcodec='libx264', crf=23, preset='fast', pix_fmt='yuv420p', format='mp4')
            .run(overwrite_output=True)
        )
        print(f"Conversión completada. Archivo guardado en: {output_file}")
    except Exception as e:
        print(f"Ocurrió un error durante la conversión de {input_file}: {e}")

# %%
# Asegurarse de que la carpeta exista después de eliminar su contenido
os.makedirs(output_path, exist_ok=True)

# Ruta de la carpeta de entrada con los archivos .txt
folder_path = '/mnt/D8E84E4DE84E2A58/Env_python/Create_video_news/0_create text/text/en/final/'

# Lista de archivos .txt en la carpeta
files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

# Ordenar los archivos si es necesario
files.sort()

# %%
for i, file in enumerate(files):
    input_path = f'videos_by_news_short/{i+1}.mp4'
    new_file = f'videos_short_formto_iphone/{i+1}.mp4'

    # Verificar si el archivo de entrada existe
    if not os.path.exists(input_path):
        print(f"El archivo de entrada no existe: {input_path}")
        continue

    convert_to_h264(input_path, new_file)
# Out:
# El archivo de entrada no existe: videos_by_news_short/1.mp4
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:19.25, start: 0.000000, bitrate: 2281 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 2140 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5e885c366000] using SAR=1/1
# [libx264 @ 0x5e885c366000] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5e885c366000] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5e885c366000] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x5e885c2a1240] video:1939kB audio:314kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.699476%
# frame=  462 fps=235 q=-1.0 Lsize=    2269kB time=00:00:19.22 bitrate= 966.8kbits/s speed=9.78x
# [libx264 @ 0x5e885c366000] frame I:5     Avg QP:12.40  size: 50369
# [libx264 @ 0x5e885c366000] frame P:140   Avg QP:15.59  size:  8585
# [libx264 @ 0x5e885c366000] frame B:317   Avg QP:19.28  size:  1675
# [libx264 @ 0x5e885c366000] consecutive B-frames:  5.2%  8.7%  3.9% 82.3%
# [libx264 @ 0x5e885c366000] mb I  I16..4: 50.8% 39.2% 10.0%
# [libx264 @ 0x5e885c366000] mb P  I16..4:  2.2%  3.1%  0.5%  P16..4:  6.1%  2.5%  1.2%  0.0%  0.0%    skip:84.4%
# [libx264 @ 0x5e885c366000] mb B  I16..4:  0.4%  0.4%  0.0%  B16..8:  4.2%  0.8%  0.0%  direct: 1.2%  skip:92.8%  L0:43.9% L1:47.5% BI: 8.6%
# [libx264 @ 0x5e885c366000] 8x8 transform intra:48.1% inter:68.1%
# [libx264 @ 0x5e885c366000] coded y,uvDC,uvAC intra: 25.9% 54.3% 23.7% inter: 1.4% 2.6% 0.3%
# [libx264 @ 0x5e885c366000] i16 v,h,dc,p: 45% 34%  7% 14%
# [libx264 @ 0x5e885c366000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 25% 21%  3%  4%  4%  4%  3%  4%
# [libx264 @ 0x5e885c366000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 24% 15%  4%  5%  6%  6%  5%  4%
# [libx264 @ 0x5e885c366000] i8c dc,h,v,p: 53% 26% 14%  7%
# [libx264 @ 0x5e885c366000] Weighted P-Frames: Y:5.0% UV:4.3%
# [libx264 @ 0x5e885c366000] ref P L0: 78.8% 21.2%
# [libx264 @ 0x5e885c366000] ref B L0: 88.0% 12.0%
# [libx264 @ 0x5e885c366000] ref B L1: 97.1%  2.9%
# [libx264 @ 0x5e885c366000] kb/s:824.86
# [aac @ 0x5e885d0f2280] Qavg: 598.523
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/2.mp4
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:11.71, start: 0.000000, bitrate: 1959 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1817 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5e1723caaac0] using SAR=1/1
# [libx264 @ 0x5e1723caaac0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5e1723caaac0] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5e1723caaac0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x5e1723c51ec0] video:1229kB audio:193kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.716298%
# frame=  281 fps=220 q=-1.0 Lsize=    1432kB time=00:00:11.67 bitrate=1004.2kbits/s speed=9.14x
# [libx264 @ 0x5e1723caaac0] frame I:2     Avg QP:15.32  size: 44716
# [libx264 @ 0x5e1723caaac0] frame P:75    Avg QP:14.71  size: 10123
# [libx264 @ 0x5e1723caaac0] frame B:204   Avg QP:18.89  size:  2004
# [libx264 @ 0x5e1723caaac0] consecutive B-frames:  1.4%  4.3%  3.2% 91.1%
# [libx264 @ 0x5e1723caaac0] mb I  I16..4: 44.2% 48.1%  7.7%
# [libx264 @ 0x5e1723caaac0] mb P  I16..4:  2.9%  4.0%  0.8%  P16..4:  8.7%  2.6%  1.1%  0.0%  0.0%    skip:79.8%
# [libx264 @ 0x5e1723caaac0] mb B  I16..4:  0.6%  0.5%  0.0%  B16..8:  5.1%  0.8%  0.0%  direct: 2.1%  skip:90.9%  L0:43.3% L1:49.0% BI: 7.6%
# [libx264 @ 0x5e1723caaac0] 8x8 transform intra:49.5% inter:76.1%
# [libx264 @ 0x5e1723caaac0] coded y,uvDC,uvAC intra: 27.8% 63.5% 22.5% inter: 1.1% 3.7% 0.3%
# [libx264 @ 0x5e1723caaac0] i16 v,h,dc,p: 33% 36%  6% 25%
# [libx264 @ 0x5e1723caaac0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 31% 20%  3%  4%  3%  5%  3%  4%
# [libx264 @ 0x5e1723caaac0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 32% 11%  5%  5%  5%  7%  5%  5%
# [libx264 @ 0x5e1723caaac0] i8c dc,h,v,p: 43% 34% 11% 12%
# [libx264 @ 0x5e1723caaac0] Weighted P-Frames: Y:2.7% UV:2.7%
# [libx264 @ 0x5e1723caaac0] ref P L0: 77.7% 22.3%
# [libx264 @ 0x5e1723caaac0] ref B L0: 88.3% 11.7%
# [libx264 @ 0x5e1723caaac0] ref B L1: 98.0%  2.0%
# [libx264 @ 0x5e1723caaac0] kb/s:859.18
# [aac @ 0x5e1724a90bc0] Qavg: 604.684
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:30.54, start: 0.000000, bitrate: 1110 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 967 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/3.mp4
# [libx264 @ 0x639489041380] using SAR=1/1
# [libx264 @ 0x639489041380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x639489041380] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x639489041380] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x639488fecb00] video:683kB audio:495kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.044775%
# frame=  733 fps=313 q=-1.0 Lsize=    1202kB time=00:00:30.51 bitrate= 322.7kbits/s speed=  13x
# [libx264 @ 0x639489041380] frame I:5     Avg QP:12.08  size: 52777
# [libx264 @ 0x639489041380] frame P:249   Avg QP:15.56  size:  1220
# [libx264 @ 0x639489041380] frame B:479   Avg QP:15.96  size:   273
# [libx264 @ 0x639489041380] consecutive B-frames:  9.1% 10.4%  2.5% 78.0%
# [libx264 @ 0x639489041380] mb I  I16..4: 56.2% 34.2%  9.6%
# [libx264 @ 0x639489041380] mb P  I16..4:  0.1%  0.2%  0.1%  P16..4:  1.8%  0.4%  0.2%  0.0%  0.0%    skip:97.1%
# [libx264 @ 0x639489041380] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.4%  0.1%  0.0%  direct: 0.1%  skip:98.4%  L0:48.6% L1:48.4% BI: 3.1%
# [libx264 @ 0x639489041380] 8x8 transform intra:36.1% inter:74.4%
# [libx264 @ 0x639489041380] coded y,uvDC,uvAC intra: 11.7% 7.2% 4.1% inter: 0.2% 0.2% 0.0%
# [libx264 @ 0x639489041380] i16 v,h,dc,p: 86% 12%  2%  1%
# [libx264 @ 0x639489041380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 52% 18% 25%  1%  1%  1%  1%  1%  1%
# [libx264 @ 0x639489041380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 28% 15%  3%  3%  3%  4%  4%  4%
# [libx264 @ 0x639489041380] i8c dc,h,v,p: 90%  6%  4%  0%
# [libx264 @ 0x639489041380] Weighted P-Frames: Y:2.0% UV:2.0%
# [libx264 @ 0x639489041380] ref P L0: 72.2% 27.8%
# [libx264 @ 0x639489041380] ref B L0: 84.3% 15.7%
# [libx264 @ 0x639489041380] ref B L1: 94.8%  5.2%
# [libx264 @ 0x639489041380] kb/s:182.99
# [aac @ 0x639489e24340] Qavg: 624.363
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:37.00, start: 0.000000, bitrate: 1936 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1794 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/4.mp4
# [libx264 @ 0x5df23015fec0] using SAR=1/1
# [libx264 @ 0x5df23015fec0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5df23015fec0] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5df23015fec0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x5df2300f2840] video:6168kB audio:601kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.430136%
# frame=  888 fps=249 q=-1.0 Lsize=    6798kB time=00:00:36.94 bitrate=1507.5kbits/s speed=10.4x
# [libx264 @ 0x5df23015fec0] frame I:5     Avg QP:13.18  size: 65161
# [libx264 @ 0x5df23015fec0] frame P:266   Avg QP:16.19  size: 13943
# [libx264 @ 0x5df23015fec0] frame B:617   Avg QP:19.84  size:  3696
# [libx264 @ 0x5df23015fec0] consecutive B-frames:  2.6% 13.7%  1.7% 82.0%
# [libx264 @ 0x5df23015fec0] mb I  I16..4: 36.3% 51.8% 12.0%
# [libx264 @ 0x5df23015fec0] mb P  I16..4:  2.5%  6.9%  0.8%  P16..4:  9.0%  2.9%  1.1%  0.0%  0.0%    skip:76.9%
# [libx264 @ 0x5df23015fec0] mb B  I16..4:  0.7%  1.3%  0.1%  B16..8:  4.6%  0.9%  0.1%  direct: 2.6%  skip:89.7%  L0:48.9% L1:45.3% BI: 5.8%
# [libx264 @ 0x5df23015fec0] 8x8 transform intra:64.2% inter:60.5%
# [libx264 @ 0x5df23015fec0] coded y,uvDC,uvAC intra: 42.8% 67.0% 26.6% inter: 2.3% 4.4% 0.8%
# [libx264 @ 0x5df23015fec0] i16 v,h,dc,p: 37% 31% 10% 23%
# [libx264 @ 0x5df23015fec0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 27% 17%  4%  3%  4%  5%  4%  6%
# [libx264 @ 0x5df23015fec0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 30% 13%  4%  5%  5%  5%  4%  5%
# [libx264 @ 0x5df23015fec0] i8c dc,h,v,p: 51% 23% 20%  6%
# [libx264 @ 0x5df23015fec0] Weighted P-Frames: Y:1.5% UV:1.5%
# [libx264 @ 0x5df23015fec0] ref P L0: 77.7% 22.3%
# [libx264 @ 0x5df23015fec0] ref B L0: 90.0% 10.0%
# [libx264 @ 0x5df23015fec0] ref B L1: 97.8%  2.2%
# [libx264 @ 0x5df23015fec0] kb/s:1365.43
# [aac @ 0x5df230f334c0] Qavg: 562.688
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:33.29, start: 0.000000, bitrate: 2196 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 2053 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 136 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/5.mp4
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55c9f9bd94c0] using SAR=1/1
# [libx264 @ 0x55c9f9bd94c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55c9f9bd94c0] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x55c9f9bd94c0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x55c9f9b71340] video:6200kB audio:544kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.389118%
# frame=  799 fps=238 q=-1.0 Lsize=    6770kB time=00:00:33.25 bitrate=1667.9kbits/s speed=9.89x
# [libx264 @ 0x55c9f9bd94c0] frame I:6     Avg QP:11.56  size: 56070
# [libx264 @ 0x55c9f9bd94c0] frame P:254   Avg QP:16.21  size: 15376
# [libx264 @ 0x55c9f9bd94c0] frame B:539   Avg QP:19.02  size:  3907
# [libx264 @ 0x55c9f9bd94c0] consecutive B-frames:  4.9% 14.5%  3.0% 77.6%
# [libx264 @ 0x55c9f9bd94c0] mb I  I16..4: 53.8% 37.6%  8.6%
# [libx264 @ 0x55c9f9bd94c0] mb P  I16..4:  3.6%  7.6%  1.0%  P16..4:  9.3%  3.0%  1.0%  0.0%  0.0%    skip:74.4%
# [libx264 @ 0x55c9f9bd94c0] mb B  I16..4:  0.8%  1.3%  0.1%  B16..8:  6.5%  1.2%  0.1%  direct: 2.5%  skip:87.4%  L0:47.4% L1:47.9% BI: 4.6%
# [libx264 @ 0x55c9f9bd94c0] 8x8 transform intra:58.4% inter:70.1%
# [libx264 @ 0x55c9f9bd94c0] coded y,uvDC,uvAC intra: 37.1% 70.4% 34.7% inter: 2.1% 4.7% 0.7%
# [libx264 @ 0x55c9f9bd94c0] i16 v,h,dc,p: 39% 31%  8% 22%
# [libx264 @ 0x55c9f9bd94c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 26% 18%  4%  5%  5%  5%  5%  5%
# [libx264 @ 0x55c9f9bd94c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 29% 12%  5%  7%  5%  7%  5%  5%
# [libx264 @ 0x55c9f9bd94c0] i8c dc,h,v,p: 46% 27% 18%  9%
# [libx264 @ 0x55c9f9bd94c0] Weighted P-Frames: Y:1.6% UV:1.6%
# [libx264 @ 0x55c9f9bd94c0] ref P L0: 77.1% 22.9%
# [libx264 @ 0x55c9f9bd94c0] ref B L0: 88.0% 12.0%
# [libx264 @ 0x55c9f9bd94c0] ref B L1: 98.2%  1.8%
# [libx264 @ 0x55c9f9bd94c0] kb/s:1525.40
# [aac @ 0x55c9fa9cd6c0] Qavg: 559.117
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:22.92, start: 0.000000, bitrate: 2247 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 2105 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/6.mp4
# [libx264 @ 0x5dee7825f380] using SAR=1/1
# [libx264 @ 0x5dee7825f380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5dee7825f380] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5dee7825f380] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x5dee781fdec0] video:2193kB audio:369kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.705006%
# frame=  550 fps=249 q=-1.0 Lsize=    2580kB time=00:00:22.89 bitrate= 923.1kbits/s speed=10.4x
# [libx264 @ 0x5dee7825f380] frame I:4     Avg QP:11.12  size: 40251
# [libx264 @ 0x5dee7825f380] frame P:216   Avg QP:14.79  size:  7122
# [libx264 @ 0x5dee7825f380] frame B:330   Avg QP:15.95  size:  1652
# [libx264 @ 0x5dee7825f380] consecutive B-frames: 14.5% 13.8%  7.6% 64.0%
# [libx264 @ 0x5dee7825f380] mb I  I16..4: 62.1% 29.4%  8.6%
# [libx264 @ 0x5dee7825f380] mb P  I16..4:  3.8%  9.3%  0.8%  P16..4:  4.1%  1.0%  0.3%  0.0%  0.0%    skip:80.6%
# [libx264 @ 0x5dee7825f380] mb B  I16..4:  1.1%  0.8%  0.0%  B16..8:  3.9%  0.7%  0.0%  direct: 1.1%  skip:92.3%  L0:46.5% L1:46.6% BI: 6.8%
# [libx264 @ 0x5dee7825f380] 8x8 transform intra:58.9% inter:70.6%
# [libx264 @ 0x5dee7825f380] coded y,uvDC,uvAC intra: 21.8% 23.7% 5.1% inter: 0.8% 1.1% 0.1%
# [libx264 @ 0x5dee7825f380] i16 v,h,dc,p: 47% 28%  6% 19%
# [libx264 @ 0x5dee7825f380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 41% 21% 21%  3%  3%  3%  3%  3%  3%
# [libx264 @ 0x5dee7825f380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 24% 12%  4%  6%  7%  6%  4%  5%
# [libx264 @ 0x5dee7825f380] i8c dc,h,v,p: 71% 14% 13%  2%
# [libx264 @ 0x5dee7825f380] Weighted P-Frames: Y:1.9% UV:1.9%
# [libx264 @ 0x5dee7825f380] ref P L0: 78.3% 21.7%
# [libx264 @ 0x5dee7825f380] ref B L0: 85.8% 14.2%
# [libx264 @ 0x5dee7825f380] ref B L1: 97.7%  2.3%
# [libx264 @ 0x5dee7825f380] kb/s:783.57
# [aac @ 0x5dee79049bc0] Qavg: 584.169
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/7.mp4
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:21.00, start: 0.000000, bitrate: 2470 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 2328 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x648eb19e5080] using SAR=1/1
# [libx264 @ 0x648eb19e5080] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x648eb19e5080] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x648eb19e5080] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x648eb199f900] video:4339kB audio:343kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.364722%
# frame=  504 fps=212 q=-1.0 Lsize=    4699kB time=00:00:20.99 bitrate=1834.0kbits/s speed=8.81x
# [libx264 @ 0x648eb19e5080] frame I:4     Avg QP:12.47  size: 50014
# [libx264 @ 0x648eb19e5080] frame P:161   Avg QP:15.85  size: 16467
# [libx264 @ 0x648eb19e5080] frame B:339   Avg QP:18.75  size:  4694
# [libx264 @ 0x648eb19e5080] consecutive B-frames:  4.2% 17.5%  3.0% 75.4%
# [libx264 @ 0x648eb19e5080] mb I  I16..4: 50.7% 39.8%  9.5%
# [libx264 @ 0x648eb19e5080] mb P  I16..4:  3.7%  7.3%  1.1%  P16..4:  9.8%  3.8%  1.3%  0.0%  0.0%    skip:73.1%
# [libx264 @ 0x648eb19e5080] mb B  I16..4:  1.0%  1.8%  0.1%  B16..8:  7.3%  1.8%  0.1%  direct: 2.6%  skip:85.3%  L0:49.8% L1:41.9% BI: 8.3%
# [libx264 @ 0x648eb19e5080] 8x8 transform intra:58.7% inter:68.8%
# [libx264 @ 0x648eb19e5080] coded y,uvDC,uvAC intra: 39.2% 67.9% 29.0% inter: 3.0% 5.4% 0.5%
# [libx264 @ 0x648eb19e5080] i16 v,h,dc,p: 30% 38%  8% 24%
# [libx264 @ 0x648eb19e5080] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 29% 19%  4%  4%  4%  6%  4%  6%
# [libx264 @ 0x648eb19e5080] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 32% 15%  4%  5%  5%  7%  4%  4%
# [libx264 @ 0x648eb19e5080] i8c dc,h,v,p: 47% 30% 14%  9%
# [libx264 @ 0x648eb19e5080] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x648eb19e5080] ref P L0: 77.7% 22.3%
# [libx264 @ 0x648eb19e5080] ref B L0: 87.9% 12.1%
# [libx264 @ 0x648eb19e5080] ref B L1: 98.1%  1.9%
# [libx264 @ 0x648eb19e5080] kb/s:1692.39
# [aac @ 0x648eb27e1180] Qavg: 592.778
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:21.79, start: 0.000000, bitrate: 2735 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 2593 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 134 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/8.mp4
# [libx264 @ 0x563a9ed72040] using SAR=1/1
# [libx264 @ 0x563a9ed72040] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x563a9ed72040] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x563a9ed72040] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# frame=  342 fps=219 q=28.0 size=    4096kB time=00:00:17.67 bitrate=1898.9kbits/s speed=11.3x
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/9.mp4
# [out#0/mp4 @ 0x563a9ed2c880] video:4168kB audio:352kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.391743%
# frame=  523 fps=268 q=-1.0 Lsize=    4539kB time=00:00:21.75 bitrate=1708.8kbits/s speed=11.2x
# [libx264 @ 0x563a9ed72040] frame I:4     Avg QP:11.64  size: 38624
# [libx264 @ 0x563a9ed72040] frame P:156   Avg QP:16.72  size: 10506
# [libx264 @ 0x563a9ed72040] frame B:363   Avg QP:19.66  size:  6817
# [libx264 @ 0x563a9ed72040] consecutive B-frames:  3.3% 11.1%  4.6% 81.1%
# [libx264 @ 0x563a9ed72040] mb I  I16..4: 56.2% 35.2%  8.5%
# [libx264 @ 0x563a9ed72040] mb P  I16..4:  1.2%  3.6%  0.9%  P16..4:  3.0%  0.9%  0.4%  0.0%  0.0%    skip:90.0%
# [libx264 @ 0x563a9ed72040] mb B  I16..4:  0.5%  0.6%  0.5%  B16..8:  2.1%  0.7%  0.1%  direct: 1.6%  skip:93.9%  L0:47.4% L1:38.8% BI:13.8%
# [libx264 @ 0x563a9ed72040] 8x8 transform intra:50.1% inter:21.3%
# [libx264 @ 0x563a9ed72040] coded y,uvDC,uvAC intra: 45.9% 47.7% 37.5% inter: 1.7% 2.0% 1.1%
# [libx264 @ 0x563a9ed72040] i16 v,h,dc,p: 48% 21% 14% 17%
# [libx264 @ 0x563a9ed72040] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 18% 26%  4%  4%  4%  4%  4%  4%
# [libx264 @ 0x563a9ed72040] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 19% 24%  6%  5%  5%  5%  5%  6%
# [libx264 @ 0x563a9ed72040] i8c dc,h,v,p: 76% 10%  9%  4%
# [libx264 @ 0x563a9ed72040] Weighted P-Frames: Y:1.3% UV:1.3%
# [libx264 @ 0x563a9ed72040] ref P L0: 72.8% 27.2%
# [libx264 @ 0x563a9ed72040] ref B L0: 87.6% 12.4%
# [libx264 @ 0x563a9ed72040] ref B L1: 95.7%  4.3%
# [libx264 @ 0x563a9ed72040] kb/s:1566.78
# [aac @ 0x563a9fb60300] Qavg: 592.220
