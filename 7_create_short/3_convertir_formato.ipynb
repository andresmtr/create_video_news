# %%
import ffmpeg
import os

# %%
# Ruta donde se deben eliminar las carpetas
output_path = 'videos_short_formto_iphone'

# Eliminar todas las carpetas en output_path
if os.path.exists(output_path):
    # Iterar sobre los elementos dentro del directorio
    for item in os.listdir(output_path):
        item_path = os.path.join(output_path, item)
        # Eliminar archivos
        if os.path.isfile(item_path):
            os.remove(item_path)
        # Eliminar carpetas y su contenido de forma recursiva
        elif os.path.isdir(item_path):
            for root, dirs, files in os.walk(item_path, topdown=False):
                for name in files:
                    os.remove(os.path.join(root, name))
                for name in dirs:
                    os.rmdir(os.path.join(root, name))
            os.rmdir(item_path)  # Finalmente eliminar la carpeta vacía
else:
    print(f"The folder {output_path} does not exist.")

# %%
def convert_to_h264(input_file, output_file):
    if not os.path.exists(input_file):
        print(f"Archivo de entrada no encontrado: {input_file}")
        return

    try:
        (
            ffmpeg
            .input(input_file)
            .output(output_file, vcodec='libx264', crf=23, preset='fast', pix_fmt='yuv420p', format='mp4')
            .run(overwrite_output=True)
        )
        print(f"Conversión completada. Archivo guardado en: {output_file}")
    except Exception as e:
        print(f"Ocurrió un error durante la conversión de {input_file}: {e}")

# %%
# Asegurarse de que la carpeta exista después de eliminar su contenido
os.makedirs(output_path, exist_ok=True)

# Ruta de la carpeta de entrada con los archivos .txt
folder_path = '/mnt/D8E84E4DE84E2A58/Env_python/Create_video_news/0_create text/text/en/final/'

# Lista de archivos .txt en la carpeta
files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

# Ordenar los archivos si es necesario
files.sort()

# %%
for i, file in enumerate(files):
    input_path = f'videos_by_news_short/{i+1}.mp4'
    new_file = f'videos_short_formto_iphone/{i+1}.mp4'

    # Verificar si el archivo de entrada existe
    if not os.path.exists(input_path):
        print(f"El archivo de entrada no existe: {input_path}")
        continue

    convert_to_h264(input_path, new_file)
# Out:
# El archivo de entrada no existe: videos_by_news_short/1.mp4
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:29.29, start: 0.000000, bitrate: 2343 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 2201 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x577401a74400] using SAR=1/1
# [libx264 @ 0x577401a74400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x577401a74400] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x577401a74400] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x577401a0ffc0] video:3645kB audio:475kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.564700%
# frame=  703 fps=263 q=-1.0 Lsize=    4144kB time=00:00:29.25 bitrate=1160.3kbits/s speed=10.9x
# [libx264 @ 0x577401a74400] frame I:4     Avg QP:13.33  size: 66342
# [libx264 @ 0x577401a74400] frame P:201   Avg QP:14.36  size:  9693
# [libx264 @ 0x577401a74400] frame B:498   Avg QP:16.11  size:  3049
# [libx264 @ 0x577401a74400] consecutive B-frames:  4.0%  4.0%  2.1% 89.9%
# [libx264 @ 0x577401a74400] mb I  I16..4: 49.5% 40.0% 10.5%
# [libx264 @ 0x577401a74400] mb P  I16..4:  1.7%  5.6%  0.7%  P16..4:  4.0%  1.5%  0.5%  0.0%  0.0%    skip:86.0%
# [libx264 @ 0x577401a74400] mb B  I16..4:  0.3%  1.2%  0.2%  B16..8:  3.1%  1.0%  0.1%  direct: 0.7%  skip:93.4%  L0:52.6% L1:40.5% BI: 6.9%
# [libx264 @ 0x577401a74400] 8x8 transform intra:66.0% inter:63.5%
# [libx264 @ 0x577401a74400] coded y,uvDC,uvAC intra: 51.4% 72.1% 30.6% inter: 1.3% 2.0% 0.2%
# [libx264 @ 0x577401a74400] i16 v,h,dc,p: 38% 24%  6% 31%
# [libx264 @ 0x577401a74400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 23% 15%  6%  6%  5%  7%  6%  8%
# [libx264 @ 0x577401a74400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 24% 13%  6%  6%  5%  7%  7%  5%
# [libx264 @ 0x577401a74400] i8c dc,h,v,p: 51% 20% 19% 10%
# [libx264 @ 0x577401a74400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x577401a74400] ref P L0: 76.8% 23.2%
# [libx264 @ 0x577401a74400] ref B L0: 91.8%  8.2%
# [libx264 @ 0x577401a74400] ref B L1: 98.2%  1.8%
# [libx264 @ 0x577401a74400] kb/s:1019.24
# [aac @ 0x577402863780] Qavg: 582.756
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:13.88, start: 0.000000, bitrate: 1157 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1013 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 137 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/2.mp4
# [libx264 @ 0x5c048d79cd80] using SAR=1/1
# [libx264 @ 0x5c048d79cd80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5c048d79cd80] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5c048d79cd80] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x5c048d746240] video:223kB audio:227kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.625371%
# frame=  333 fps=288 q=-1.0 Lsize=     463kB time=00:00:13.83 bitrate= 273.9kbits/s speed=  12x
# [libx264 @ 0x5c048d79cd80] frame I:3     Avg QP:13.98  size: 54472
# [libx264 @ 0x5c048d79cd80] frame P:84    Avg QP:13.89  size:   469
# [libx264 @ 0x5c048d79cd80] frame B:246   Avg QP:15.64  size:   102
# [libx264 @ 0x5c048d79cd80] consecutive B-frames:  1.5%  0.0%  0.0% 98.5%
# [libx264 @ 0x5c048d79cd80] mb I  I16..4: 50.8% 38.9% 10.3%
# [libx264 @ 0x5c048d79cd80] mb P  I16..4:  0.2%  0.1%  0.0%  P16..4:  0.9%  0.1%  0.1%  0.0%  0.0%    skip:98.5%
# [libx264 @ 0x5c048d79cd80] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.2%  0.0%  0.0%  direct: 0.0%  skip:99.8%  L0:52.4% L1:47.1% BI: 0.5%
# [libx264 @ 0x5c048d79cd80] 8x8 transform intra:36.8% inter:69.8%
# [libx264 @ 0x5c048d79cd80] coded y,uvDC,uvAC intra: 9.2% 10.2% 6.4% inter: 0.0% 0.2% 0.0%
# [libx264 @ 0x5c048d79cd80] i16 v,h,dc,p: 79% 18%  2%  1%
# [libx264 @ 0x5c048d79cd80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 54% 28% 16%  0%  0%  0%  0%  0%  1%
# [libx264 @ 0x5c048d79cd80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 27% 12%  4%  3%  4%  4%  5%  4%
# [libx264 @ 0x5c048d79cd80] i8c dc,h,v,p: 84% 13%  3%  1%
# [libx264 @ 0x5c048d79cd80] Weighted P-Frames: Y:3.6% UV:3.6%
# [libx264 @ 0x5c048d79cd80] ref P L0: 82.1% 17.9%
# [libx264 @ 0x5c048d79cd80] ref B L0: 89.4% 10.6%
# [libx264 @ 0x5c048d79cd80] ref B L1: 94.9%  5.1%
# [libx264 @ 0x5c048d79cd80] kb/s:131.47
# [aac @ 0x5c048e580680] Qavg: 592.735
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:17.71, start: 0.000000, bitrate: 2073 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1930 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 136 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/3.mp4
# [libx264 @ 0x5870f9da3100] using SAR=1/1
# [libx264 @ 0x5870f9da3100] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5870f9da3100] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5870f9da3100] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x5870f9ce74c0] video:1790kB audio:287kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.708478%
# frame=  425 fps=259 q=-1.0 Lsize=    2092kB time=00:00:17.69 bitrate= 968.6kbits/s speed=10.8x
# [libx264 @ 0x5870f9da3100] frame I:3     Avg QP:12.13  size: 72532
# [libx264 @ 0x5870f9da3100] frame P:111   Avg QP:14.80  size:  8649
# [libx264 @ 0x5870f9da3100] frame B:311   Avg QP:19.40  size:  2105
# [libx264 @ 0x5870f9da3100] consecutive B-frames:  0.7%  4.7%  1.4% 93.2%
# [libx264 @ 0x5870f9da3100] mb I  I16..4: 53.2% 34.2% 12.6%
# [libx264 @ 0x5870f9da3100] mb P  I16..4:  1.3%  2.9%  0.5%  P16..4:  8.8%  2.7%  1.1%  0.0%  0.0%    skip:82.8%
# [libx264 @ 0x5870f9da3100] mb B  I16..4:  0.3%  0.8%  0.1%  B16..8:  4.5%  0.9%  0.1%  direct: 1.2%  skip:92.1%  L0:44.5% L1:47.6% BI: 7.9%
# [libx264 @ 0x5870f9da3100] 8x8 transform intra:56.8% inter:70.7%
# [libx264 @ 0x5870f9da3100] coded y,uvDC,uvAC intra: 35.8% 45.2% 14.1% inter: 1.6% 1.9% 0.1%
# [libx264 @ 0x5870f9da3100] i16 v,h,dc,p: 47% 20%  7% 27%
# [libx264 @ 0x5870f9da3100] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 27% 19%  5%  7%  5%  8%  3%  7%
# [libx264 @ 0x5870f9da3100] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 23% 13%  7%  8%  7%  6%  6%  6%
# [libx264 @ 0x5870f9da3100] i8c dc,h,v,p: 61% 22% 12%  5%
# [libx264 @ 0x5870f9da3100] Weighted P-Frames: Y:2.7% UV:2.7%
# [libx264 @ 0x5870f9da3100] ref P L0: 74.1% 25.9%
# [libx264 @ 0x5870f9da3100] ref B L0: 85.6% 14.4%
# [libx264 @ 0x5870f9da3100] ref B L1: 97.5%  2.5%
# [libx264 @ 0x5870f9da3100] kb/s:827.70
# [aac @ 0x5870fab33d00] Qavg: 602.287
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:21.63, start: 0.000000, bitrate: 1843 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1700 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 136 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/4.mp4
# [libx264 @ 0x578f8ce49080] using SAR=1/1
# [libx264 @ 0x578f8ce49080] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x578f8ce49080] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x578f8ce49080] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x578f8ce03880] video:1196kB audio:353kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.133107%
# frame=  519 fps=277 q=-1.0 Lsize=    1567kB time=00:00:21.59 bitrate= 594.5kbits/s speed=11.5x
# [libx264 @ 0x578f8ce49080] frame I:5     Avg QP: 9.96  size: 40655
# [libx264 @ 0x578f8ce49080] frame P:144   Avg QP:14.17  size:  4166
# [libx264 @ 0x578f8ce49080] frame B:370   Avg QP:14.96  size:  1138
# [libx264 @ 0x578f8ce49080] consecutive B-frames:  4.2%  1.5%  1.7% 92.5%
# [libx264 @ 0x578f8ce49080] mb I  I16..4: 58.0% 34.4%  7.5%
# [libx264 @ 0x578f8ce49080] mb P  I16..4:  1.8%  2.9%  0.2%  P16..4:  3.2%  0.6%  0.2%  0.0%  0.0%    skip:91.0%
# [libx264 @ 0x578f8ce49080] mb B  I16..4:  0.4%  0.3%  0.0%  B16..8:  1.7%  0.3%  0.0%  direct: 0.6%  skip:96.6%  L0:45.1% L1:46.1% BI: 8.9%
# [libx264 @ 0x578f8ce49080] 8x8 transform intra:47.3% inter:68.5%
# [libx264 @ 0x578f8ce49080] coded y,uvDC,uvAC intra: 20.7% 45.1% 16.7% inter: 0.5% 1.3% 0.1%
# [libx264 @ 0x578f8ce49080] i16 v,h,dc,p: 54% 21%  5% 20%
# [libx264 @ 0x578f8ce49080] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 21% 22%  3%  5%  3%  6%  3%  3%
# [libx264 @ 0x578f8ce49080] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 23% 11%  4%  6%  6%  7%  5%  3%
# [libx264 @ 0x578f8ce49080] i8c dc,h,v,p: 58% 20% 12% 10%
# [libx264 @ 0x578f8ce49080] Weighted P-Frames: Y:3.5% UV:3.5%
# [libx264 @ 0x578f8ce49080] ref P L0: 76.1% 23.9%
# [libx264 @ 0x578f8ce49080] ref B L0: 82.7% 17.3%
# [libx264 @ 0x578f8ce49080] ref B L1: 95.9%  4.1%
# [libx264 @ 0x578f8ce49080] kb/s:452.92
# [aac @ 0x578f8dc27e80] Qavg: 598.510
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:26.38, start: 0.000000, bitrate: 1488 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1346 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/5.mp4
# [libx264 @ 0x611142d87100] using SAR=1/1
# [libx264 @ 0x611142d87100] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x611142d87100] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x611142d87100] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x611142cd5200] video:953kB audio:427kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.540327%
# frame=  633 fps=298 q=-1.0 Lsize=    1401kB time=00:00:26.33 bitrate= 435.8kbits/s speed=12.4x
# [libx264 @ 0x611142d87100] frame I:5     Avg QP:11.97  size: 56053
# [libx264 @ 0x611142d87100] frame P:158   Avg QP:14.19  size:  2534
# [libx264 @ 0x611142d87100] frame B:470   Avg QP:16.33  size:   626
# [libx264 @ 0x611142d87100] consecutive B-frames:  0.8%  0.3%  0.9% 97.9%
# [libx264 @ 0x611142d87100] mb I  I16..4: 47.7% 41.2% 11.1%
# [libx264 @ 0x611142d87100] mb P  I16..4:  0.4%  1.0%  0.1%  P16..4:  4.9%  1.3%  0.5%  0.0%  0.0%    skip:91.8%
# [libx264 @ 0x611142d87100] mb B  I16..4:  0.2%  0.1%  0.0%  B16..8:  2.2%  0.3%  0.0%  direct: 0.5%  skip:96.7%  L0:40.9% L1:55.3% BI: 3.9%
# [libx264 @ 0x611142d87100] 8x8 transform intra:46.9% inter:76.5%
# [libx264 @ 0x611142d87100] coded y,uvDC,uvAC intra: 15.5% 24.2% 11.6% inter: 0.4% 0.8% 0.0%
# [libx264 @ 0x611142d87100] i16 v,h,dc,p: 74% 17%  5%  5%
# [libx264 @ 0x611142d87100] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 16% 30%  2%  2%  3%  2%  2%  1%
# [libx264 @ 0x611142d87100] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 28% 10%  5%  5%  5%  5%  5%  4%
# [libx264 @ 0x611142d87100] i8c dc,h,v,p: 76% 12% 10%  2%
# [libx264 @ 0x611142d87100] Weighted P-Frames: Y:3.2% UV:3.2%
# [libx264 @ 0x611142d87100] ref P L0: 69.8% 30.2%
# [libx264 @ 0x611142d87100] ref B L0: 79.4% 20.6%
# [libx264 @ 0x611142d87100] ref B L1: 94.4%  5.6%
# [libx264 @ 0x611142d87100] kb/s:295.65
# [aac @ 0x611143b13d00] Qavg: 581.454
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:25.79, start: 0.000000, bitrate: 2390 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 2248 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/6.mp4
# [libx264 @ 0x55596e2b33c0] using SAR=1/1
# [libx264 @ 0x55596e2b33c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55596e2b33c0] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x55596e2b33c0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x55596e254e40] video:3463kB audio:417kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.531254%
# frame=  619 fps=246 q=-1.0 Lsize=    3901kB time=00:00:25.75 bitrate=1240.9kbits/s speed=10.2x
# [libx264 @ 0x55596e2b33c0] frame I:5     Avg QP:12.47  size: 82919
# [libx264 @ 0x55596e2b33c0] frame P:197   Avg QP:15.19  size:  9507
# [libx264 @ 0x55596e2b33c0] frame B:417   Avg QP:17.90  size:  3017
# [libx264 @ 0x55596e2b33c0] consecutive B-frames:  6.3% 10.7%  2.9% 80.1%
# [libx264 @ 0x55596e2b33c0] mb I  I16..4: 45.0% 42.8% 12.2%
# [libx264 @ 0x55596e2b33c0] mb P  I16..4:  3.9%  6.4%  0.7%  P16..4:  7.3%  1.9%  0.7%  0.0%  0.0%    skip:79.1%
# [libx264 @ 0x55596e2b33c0] mb B  I16..4:  0.9%  1.1%  0.1%  B16..8:  5.5%  1.1%  0.1%  direct: 2.4%  skip:88.8%  L0:45.0% L1:47.1% BI: 7.9%
# [libx264 @ 0x55596e2b33c0] 8x8 transform intra:55.1% inter:73.3%
# [libx264 @ 0x55596e2b33c0] coded y,uvDC,uvAC intra: 27.4% 57.1% 15.2% inter: 1.4% 3.9% 0.3%
# [libx264 @ 0x55596e2b33c0] i16 v,h,dc,p: 31% 32%  8% 29%
# [libx264 @ 0x55596e2b33c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 30% 21%  3%  4%  3%  5%  3%  4%
# [libx264 @ 0x55596e2b33c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 32% 12%  4%  5%  5%  6%  5%  5%
# [libx264 @ 0x55596e2b33c0] i8c dc,h,v,p: 47% 30% 14%  9%
# [libx264 @ 0x55596e2b33c0] Weighted P-Frames: Y:2.5% UV:2.5%
# [libx264 @ 0x55596e2b33c0] ref P L0: 79.2% 20.8%
# [libx264 @ 0x55596e2b33c0] ref B L0: 88.0% 12.0%
# [libx264 @ 0x55596e2b33c0] ref B L1: 97.3%  2.7%
# [libx264 @ 0x55596e2b33c0] kb/s:1099.82
# [aac @ 0x55596f097b00] Qavg: 600.917
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:15.63, start: 0.000000, bitrate: 2050 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 1908 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 135 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/7.mp4
# [libx264 @ 0x56d0069e9d40] using SAR=1/1
# [libx264 @ 0x56d0069e9d40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x56d0069e9d40] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x56d0069e9d40] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x56d00698e1c0] video:1993kB audio:254kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.579911%
# frame=  375 fps=219 q=-1.0 Lsize=    2260kB time=00:00:15.60 bitrate=1186.5kbits/s speed= 9.1x
# [libx264 @ 0x56d0069e9d40] frame I:3     Avg QP:10.50  size: 42317
# [libx264 @ 0x56d0069e9d40] frame P:119   Avg QP:14.90  size:  9329
# [libx264 @ 0x56d0069e9d40] frame B:253   Avg QP:18.11  size:  3175
# [libx264 @ 0x56d0069e9d40] consecutive B-frames:  5.6% 12.3%  3.2% 78.9%
# [libx264 @ 0x56d0069e9d40] mb I  I16..4: 64.2% 28.1%  7.6%
# [libx264 @ 0x56d0069e9d40] mb P  I16..4:  3.5% 10.0%  0.6%  P16..4:  8.3%  1.9%  0.6%  0.0%  0.0%    skip:75.0%
# [libx264 @ 0x56d0069e9d40] mb B  I16..4:  1.1%  1.6%  0.1%  B16..8:  7.8%  1.2%  0.0%  direct: 2.3%  skip:85.9%  L0:49.4% L1:47.0% BI: 3.6%
# [libx264 @ 0x56d0069e9d40] 8x8 transform intra:62.6% inter:79.4%
# [libx264 @ 0x56d0069e9d40] coded y,uvDC,uvAC intra: 27.9% 52.9% 13.0% inter: 1.5% 3.4% 0.0%
# [libx264 @ 0x56d0069e9d40] i16 v,h,dc,p: 43% 31% 10% 16%
# [libx264 @ 0x56d0069e9d40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 25% 22%  4%  5%  5%  5%  4%  4%
# [libx264 @ 0x56d0069e9d40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 28% 12%  5%  8%  6%  7%  5%  4%
# [libx264 @ 0x56d0069e9d40] i8c dc,h,v,p: 53% 25% 17%  5%
# [libx264 @ 0x56d0069e9d40] Weighted P-Frames: Y:2.5% UV:2.5%
# [libx264 @ 0x56d0069e9d40] ref P L0: 78.1% 21.9%
# [libx264 @ 0x56d0069e9d40] ref B L0: 85.7% 14.3%
# [libx264 @ 0x56d0069e9d40] ref B L1: 96.9%  3.1%
# [libx264 @ 0x56d0069e9d40] kb/s:1044.69
# [aac @ 0x56d0077d1700] Qavg: 620.091
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/8.mp4
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos_by_news_short/9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:20.67, start: 0.000000, bitrate: 2481 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), gbrp(pc, gbr/unknown/unknown, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 2340 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 h264_nvenc
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 134 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5c005943c2c0] using SAR=1/1
# [libx264 @ 0x5c005943c2c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5c005943c2c0] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5c005943c2c0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=36 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos_short_formto_iphone/9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 aac
# frame=  327 fps=208 q=28.0 size=    2560kB time=00:00:17.04 bitrate=1230.5kbits/s speed=10.8x
# Conversión completada. Archivo guardado en: videos_short_formto_iphone/9.mp4
# [out#0/mp4 @ 0x5c00593db340] video:4424kB audio:336kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.352789%
# frame=  496 fps=239 q=-1.0 Lsize=    4777kB time=00:00:20.64 bitrate=1895.6kbits/s speed=9.96x
# [libx264 @ 0x5c005943c2c0] frame I:4     Avg QP:11.41  size: 68729
# [libx264 @ 0x5c005943c2c0] frame P:158   Avg QP:17.24  size: 16167
# [libx264 @ 0x5c005943c2c0] frame B:334   Avg QP:18.92  size:  5090
# [libx264 @ 0x5c005943c2c0] consecutive B-frames:  6.0% 10.9%  4.8% 78.2%
# [libx264 @ 0x5c005943c2c0] mb I  I16..4: 59.3% 28.9% 11.9%
# [libx264 @ 0x5c005943c2c0] mb P  I16..4:  2.1%  6.2%  1.2%  P16..4:  7.4%  2.8%  1.1%  0.0%  0.0%    skip:79.3%
# [libx264 @ 0x5c005943c2c0] mb B  I16..4:  0.5%  1.3%  0.1%  B16..8:  4.5%  1.4%  0.2%  direct: 2.1%  skip:89.8%  L0:49.1% L1:40.7% BI:10.1%
# [libx264 @ 0x5c005943c2c0] 8x8 transform intra:59.5% inter:52.3%
# [libx264 @ 0x5c005943c2c0] coded y,uvDC,uvAC intra: 48.7% 65.7% 29.6% inter: 2.7% 3.9% 1.0%
# [libx264 @ 0x5c005943c2c0] i16 v,h,dc,p: 40% 27% 10% 23%
# [libx264 @ 0x5c005943c2c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 28% 16%  5%  5%  5%  7%  5%  8%
# [libx264 @ 0x5c005943c2c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 28% 13%  5%  5%  5%  8%  5%  6%
# [libx264 @ 0x5c005943c2c0] i8c dc,h,v,p: 55% 24% 16%  6%
# [libx264 @ 0x5c005943c2c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5c005943c2c0] ref P L0: 78.2% 21.8%
# [libx264 @ 0x5c005943c2c0] ref B L0: 85.9% 14.1%
# [libx264 @ 0x5c005943c2c0] ref B L1: 97.0%  3.0%
# [libx264 @ 0x5c005943c2c0] kb/s:1753.21
# [aac @ 0x5c005a233e80] Qavg: 583.917
